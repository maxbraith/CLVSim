# %%
import pandas as pd
import numpy as np
import uuid

# %%
df = pd.read_csv("trainSequences.csv", header=None, names=range(231))
df.columns = df.iloc[0]
df = df[1:]
df.reset_index(drop=True, inplace=True)
df
# Out:
# /var/folders/pw/f4_6q0l977bcqprlylly2d1w0000gq/T/ipykernel_5856/3664135840.py:1: DtypeWarning: Columns (192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("trainSequences.csv", header=None, names=range(231))
# 0                       fighter  \
# 0                    Daichi Abe
# 1                    Juan Adams
# 2                 Klidson Abreu
# 3                 Ricardo Abreu
# 4                 Kevin Aguilar
# ...                         ...
# 9639                 Fares Ziam
# 9640  Elizeu Zaleski dos Santos
# 9641                 Fares Ziam
# 9642                 Rani Yahya
# 9643                 Fares Ziam
#
# 0                                             event        date  \
# 0           UFC Fight Night 132: Cowboy vs. Edwards  2018-06-23
# ...

# %%
df['fighter'] = df['fighter'].replace('Gilbert Aldana', 'Hector Aldana')

df['fighter'] = df['fighter'].replace('YoungJae Song', 'Kenan Song')

df['fighter'] = df['fighter'].replace('Bill Duvall', 'Bill Algeo')

df['fighter'] = df['fighter'].replace('Joel Thomas', 'Joel Alvarez')

df['fighter'] = df['fighter'].replace('Rameau Thierry Sokoudjou', 'Rameau Sokoudjou')

df['fighter'] = df['fighter'].replace('Dan Molina', 'Jeff Molina')

df['fighter'] = df['fighter'].replace('Bruno Silva', 'Bruno Gustavo da Silva')

df['fighter'] = df['fighter'].replace('David Velasquez', 'Cain Velasquez')

df['fighter'] = df['fighter'].replace('Maria Oliveira', 'Maria de Oliveira Neta')

df['fighter'] = df['fighter'].replace('Yan Pellerin', 'Petr Yan')

df['fighter'] = df['fighter'].replace('Cesar Marscucci', 'Cesar Almeida')

df['fighter'] = df['fighter'].replace('Sam Hoger', 'Sam Alvey')

df['fighter'] = df['fighter'].replace('Montserrat Conejo Ruiz', 'Montserrat Ruiz')

df['fighter'] = df['fighter'].replace('Ovince Saint Preux', 'Ovince St Preux')

df['fighter'] = df['fighter'].replace('Rogerio Nogueira', 'Antonio Rogerio Nogueira')

df['fighter'] = df['fighter'].replace('Khalil Rountree Jr', 'Khalil Rountree')

df['fighter'] = df['fighter'].replace('Yohan Banks', 'Yohan Lainesse')

df['fighter'] = df['fighter'].replace('Edson Silva', 'Edson Barboza')

df['fighter'] = df['fighter'].replace('Rolando Dy', 'Rolando Bedoya')

df['fighter'] = df['fighter'].replace('Scott Ferrozzo', 'Brad Scott')

df['fighter'] = df['fighter'].replace('Scott Bessac', 'Brad Scott')

df['fighter'] = df['fighter'].replace('Scott Fiedler', 'Brad Scott')

df['fighter'] = df['fighter'].replace('Ion Cherdivara', 'Ion Cutelaba')

df['fighter'] = df['fighter'].replace('Luiz Dutra', 'Luiz Dutra Jr')

df['fighter'] = df['fighter'].replace('Glaico Franca Moreira', 'Glaico Franca')

df['fighter'] = df['fighter'].replace('Joshua Burkman', 'Josh Burkman')

df['fighter'] = df['fighter'].replace('Jadson Costa', 'Alessandro Costa')

df['fighter'] = df['fighter'].replace('Henrique Da Silva', 'Claudio Henrique Da Silva')

df['fighter'] = df['fighter'].replace('Claudio Silva', 'Claudio Henrique Da Silva')

df['fighter'] = df['fighter'].replace('Henrique Da Silva Lopes', 'Claudio Henrique Da Silva')

df['fighter'] = df['fighter'].replace('Henrique da Silva', 'Claudio Henrique Da Silva')

df['fighter'] = df['fighter'].replace('Ion Curelaba', 'Ion Cutelaba')
df['opponent'] = df['opponent'].replace('Ion Curelaba', 'Ion Cutelaba')

df['fighter'] = df['fighter'].replace('JP Buys', 'Cheyanne Buys')

df['fighter'] = df['fighter'].replace('John Dixson', 'Carls John De Tomas')

df['fighter'] = df['fighter'].replace('John Campetella', 'Carls John De Tomas')

df['fighter'] = df['fighter'].replace('John Lober', 'Carls John De Tomas')

df['fighter'] = df['fighter'].replace('John Matua', 'Carls John De Tomas')

df['fighter'] = df['fighter'].replace('John Renken', 'Carls John De Tomas')

df['fighter'] = df['fighter'].replace('Luiz Cane', 'Luis Cane')

df['fighter'] = df['fighter'].replace('Daniel Lacerda', 'Daniel da Silva Lacerda')

df['fighter'] = df['fighter'].replace('Emily Fernandez', 'Emily Ducote')

df['fighter'] = df['fighter'].replace('KB Bhullar', 'Arjan Bhullar')

df['fighter'] = df['fighter'].replace('Brad Gumm', 'Brad Blackburn')

df['fighter'] = df['fighter'].replace('RJ Clifford', 'Clifford Starks')

df['fighter'] = df['fighter'].replace('Akira Kikuchi', 'Akira Corassani')

df['fighter'] = df['fighter'].replace('Brady Fink', 'Brady Hiestand')

df['fighter'] = df['fighter'].replace('Willie Peeters', 'Willie Gates')

df['fighter'] = df['fighter'].replace('Fabio Gurgel', 'Jorge Gurgel')

df['fighter'] = df['fighter'].replace('Justin Hawes', 'Phil Hawes')

df['fighter'] = df['fighter'].replace('Ed Herman', 'Dave Herman')

df['fighter'] = df['fighter'].replace('Herman Renting', 'Dave Herman')

df['fighter'] = df['fighter'].replace('Alvaro Herrera Mendoza', 'Alvaro Herrera')

df['fighter'] = df['fighter'].replace('Paul Herrera', 'Alvaro Herrera')

df['fighter'] = df['fighter'].replace('Kurt Osiander', 'Kurt Holobaugh')

df['fighter'] = df['fighter'].replace('Jorge Interiano', 'Ivan Jorge')

df['fighter'] = df['fighter'].replace('Phil Johns', 'Brett Johns')

df['fighter'] = df['fighter'].replace('Patrick Kaase', 'Alan Patrick')

df['fighter'] = df['fighter'].replace('Dong Hyun Ma', 'Dong Hyun Kim')

df['fighter'] = df['fighter'].replace('Akira Kikuchi', 'Akira Corassani')

df['fighter'] = df['fighter'].replace('Andrei Kopylov', 'Roman Kopylov')

df['fighter'] = df['fighter'].replace('Eun Soo Lee', 'Jin Soo Son')

df['fighter'] = df['fighter'].replace('Justin Martin', 'Anthony Rocco Martin')

df['fighter'] = df['fighter'].replace('Joe Martin', 'Anthony Rocco Martin')

df['fighter'] = df['fighter'].replace('Joao Roque', 'Roque Martinez')

df['fighter'] = df['fighter'].replace('Flavio Luiz Moura', 'Eduarda Moura')

df['fighter'] = df['fighter'].replace('Mario Neto', 'Antonio Braga Neto')

df['fighter'] = df['fighter'].replace('Josh Neal', 'Geoff Neal')

df['fighter'] = df['fighter'].replace('Rodrigo Ruas', 'Antonio Rodrigo Nogueira')

df['fighter'] = df['fighter'].replace("TJ O'Brien", "Jake O'Brien")

df['fighter'] = df['fighter'].replace('Tulio Palhares', 'Rousimar Palhares')

df['fighter'] = df['fighter'].replace('Dave Phillips', 'Aaron Phillips')

df['fighter'] = df['fighter'].replace('Kyle Reyes', 'Alex Reyes')

df['fighter'] = df['fighter'].replace('Denis Sobolev', 'Benoit Saint Denis')

df['fighter'] = df['fighter'].replace('Chad W Saunders', 'Ben Saunders')

df['fighter'] = df['fighter'].replace('Wade Shipp', 'Chris Wade')

df['fighter'] = df['fighter'].replace('Erick Wanderlei', 'Wanderlei Silva')

df['fighter'] = df['fighter'].replace('Song Kenan', 'Kenan Song')

df['fighter'] = df['fighter'].replace('Aaron Trujillo', 'Abel Trujillo')

df['fighter'] = df['fighter'].replace('Won Jin Eoh', 'Bala Jin')

df['fighter'] = df['fighter'].replace('Jin Bala', 'Bala Jin')

df['fighter'] = df['fighter'].replace('Jin Oh Kim', 'Bala Jin')

df['fighter'] = df['fighter'].replace('Jorge Oliveira', 'Jorge de Oliveira')

df['fighter'] = df['fighter'].replace('Houston Dorr', 'Brian Houston')

df['fighter'] = df['fighter'].replace('Jamie Houston', 'Brian Houston')

df['fighter'] = df['fighter'].replace('Ray Steinbeiss', 'Steve Steinbeiss')

df['fighter'] = df['fighter'].replace('Jim Crute', 'Jimmy Crute')

df['fighter'] = df['fighter'].replace('Tiago dos Santos e Silva', 'Tiago Dos Santos')

df['fighter'] = df['fighter'].replace('Antonio Dos Santos', 'Antonio Dos Santos Jr')

df['fighter'] = df['fighter'].replace('Diego Ferreira', 'Carlos Diego Ferreira')

df['fighter'] = df['fighter'].replace('Billy Ray Goff', 'Billy Goff')

df['fighter'] = df['fighter'].replace('Dmitry Sosnovskiy', 'Dmitriy Sosnovskiy')

df['fighter'] = df['fighter'].replace('Lina Lansberg', 'Lina Akhtar Lansberg')

df['fighter'] = df['fighter'].replace('Geoffrey Neal', 'Geoff Neal')

df['fighter'] = df['fighter'].replace('Ricardo Ramos', 'Ricardo Lucas Ramos')

df['fighter'] = df['fighter'].replace('Rodolfo Rubio Perez', 'Rodolfo Rubio')

df['fighter'] = df['fighter'].replace('Zhang Weili', 'Weili Zhang')

df['fighter'] = df['fighter'].replace('Yan Xiaonan', 'Xiaonan Yan')

df['fighter'] = df['fighter'].replace('Bibulatov Magomed', 'Magomed Bibulatov')

df['fighter'] = df['fighter'].replace('Wang Cong', 'Cong Wang')

df['fighter'] = df['fighter'].replace('Batgerel Danaa', 'Danaa Batgerel')

df['fighter'] = df['fighter'].replace('Carlos Leal', 'Carlos Leal Miranda')

df['fighter'] = df['fighter'].replace('Yuri Vaulin', 'Yuri Alcantara')

df['fighter'] = df['fighter'].replace('Zhang Tiequan', 'Tiequan Zhang')

df['fighter'] = df['fighter'].replace('Maheshate', 'Hayisaer Maheshate')

df['fighter'] = df['fighter'].replace('Kyung Ho Kang', 'Kang Kyung-Ho')

df['fighter'] = df['fighter'].replace('Li Jingliang', 'Jingliang Li')

df['fighter'] = df['fighter'].replace('Pingyuan Liu', 'Liu Pingyuan')

df['fighter'] = df['fighter'].replace('Zhang Tiequan', 'Tiequan Zhang')

df['fighter'] = df['fighter'].replace('Ian Garry', 'Ian Machado Garry')

df['opponent'] = df['opponent'].replace('Ian Garry', 'Ian Machado Garry')

df = df.drop_duplicates().reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/python38_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# ~/anaconda3/envs/python38_env/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/python38_env/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'oponnent'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.to_csv('cleanerSequences.csv', index=False)

# %%
df
# Out:
# 0                       fighter  \
# 0                    Daichi Abe
# 1                    Juan Adams
# 2                 Klidson Abreu
# 3                 Ricardo Abreu
# 4                 Kevin Aguilar
# ...                         ...
# 9330                 Fares Ziam
# 9331  Elizeu Zaleski dos Santos
# 9332                 Fares Ziam
# 9333                 Rani Yahya
# 9334                 Fares Ziam
#
# 0                                             event        date  \
# 0           UFC Fight Night 132: Cowboy vs. Edwards  2018-06-23
# 1              UFC on ESPN 4: Dos Anjos vs. Edwards  2019-07-20
# 2                 UFC on ESPN+ 21: Zabit vs. Kattar  2019-11-09
# 3         UFC Fight Night 68: Henderson vs. Boetsch  2015-06-06
# 4                    UFC 262: Oliveira vs. Chandler  2021-05-15
# ...                                             ...         ...
# 9330                UFC 263: Adesanya vs. Vettori 2  2021-06-12
# ...

# %%
df_clean = df.copy()

# %%
def clean_and_sort(name):
    cleaned = str(name).replace("'", '').replace(' ', '').replace('-', '').lower()
    return cleaned
    #return ''.join(sorted(cleaned))

# %%
df_clean['fighter'] = df_clean['fighter'].apply(clean_and_sort)
df_clean['opponent'] = df_clean['opponent'].apply(clean_and_sort)
df_clean.head()
# Out:
# 0       fighter                                      event        date  \
# 0     daichiabe    UFC Fight Night 132: Cowboy vs. Edwards  2018-06-23
# 1     juanadams       UFC on ESPN 4: Dos Anjos vs. Edwards  2019-07-20
# 2  klidsonabreu          UFC on ESPN+ 21: Zabit vs. Kattar  2019-11-09
# 3  ricardoabreu  UFC Fight Night 68: Henderson vs. Boetsch  2015-06-06
# 4  kevinaguilar             UFC 262: Oliveira vs. Chandler  2021-05-15
#
# 0        opponent                         timestep-1  \
# 0     lijingliang  2018-06-13 12:09:00 - price: +240
# 1       greghardy  2019-06-30 17:33:00 - price: -155
# 2  shamilgamzatov  2019-10-28 12:36:00 - price: +190
# 3     jakecollier  2015-05-30 19:18:00 - price: -210
# 4      tuckerlutz  2021-04-26 17:20:00 - price: -110
#
# 0                         timestep-2                         timestep-3  \
# 0  2018-06-13 12:21:00 - price: +325  2018-06-13 13:42:00 - price: +315
# ...

# %%
df.insert(0, 'fight_id', np.nan)
df.head()
# Out:
# 0  fight_id        fighter                                      event  \
# 0       NaN     Daichi Abe    UFC Fight Night 132: Cowboy vs. Edwards
# 1       NaN     Juan Adams       UFC on ESPN 4: Dos Anjos vs. Edwards
# 2       NaN  Klidson Abreu          UFC on ESPN+ 21: Zabit vs. Kattar
# 3       NaN  Ricardo Abreu  UFC Fight Night 68: Henderson vs. Boetsch
# 4       NaN  Kevin Aguilar             UFC 262: Oliveira vs. Chandler
#
# 0        date         opponent                         timestep-1  \
# 0  2018-06-23     Li Jingliang  2018-06-13 12:09:00 - price: +240
# 1  2019-07-20       Greg Hardy  2019-06-30 17:33:00 - price: -155
# 2  2019-11-09  Shamil Gamzatov  2019-10-28 12:36:00 - price: +190
# 3  2015-06-06     Jake Collier  2015-05-30 19:18:00 - price: -210
# 4  2021-05-15      Tucker Lutz  2021-04-26 17:20:00 - price: -110
#
# 0                         timestep-2                         timestep-3  \
# ...

# %%
for index, row in df.iterrows():
    fighter = df_clean.loc[index, 'fighter']
    opponent = df_clean.loc[index, 'opponent']
    date = row['date']
    fight_id = row['fight_id']

    if not pd.isna(fight_id):
        continue

    opposing_sequence = df[
        (df_clean['fighter'] == opponent) &
        (df_clean['opponent'] == fighter) &
        (df_clean['date'] == date)
    ]

    if not opposing_sequence.empty:
        new_uuid = uuid.uuid4()
        df.loc[index, 'fight_id'] = new_uuid
        df.loc[opposing_sequence.index[0], 'fight_id'] = new_uuid

# %%
print(df['fight_id'].isna().sum())
# Out:
# 1539

# %%
df[df['fight_id'].isna()].reset_index().to_csv('missing_fight_ids.csv', index=False)

# %%
df.to_csv('trainSequencesKeys.csv')

# %%
df = pd.read_csv("missing_fight_ids.csv", header=None, names=range(231))
df.columns = df.iloc[0]
df = df[1:]
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
# ('index', 'fight_id')             fighter  \
# 0                              Daichi Abe
# 1                      Mansur Abdul-Malik
# 2                            Nick Aguirre
# 3                             Amir Albazi
# 4                           Junior Albini
#
# ('index', 'fight_id')                                    event        date  \
# 0                      UFC Fight Night 132: Cowboy vs. Edwards  2018-06-23
# 1                                                          UFC  2024-11-10
# 2                                          UFC Fight Night 218  2023-01-14
# 3                            UFC on ESPN: Hermansson vs. Allen  2023-06-03
# 4                                UFC 224: Nunes vs. Pennington  2018-05-12
#
# ('index', 'fight_id')         opponent                         timestep-1  \
# 0                         Li Jingliang  2018-06-13 12:09:00 - price: +240
# 1                      Dusko Todorovic  2024-10-27 17:16:00 - price: -360
# ...

# %%
df_clean = df.copy()
df_clean['fighter'] = df_clean['fighter'].apply(clean_and_sort)
df_clean['opponent'] = df_clean['opponent'].apply(clean_and_sort)
df_clean.head()
# Out:
# ('index', 'fight_id')           fighter  \
# 0                             daichiabe
# 1                      mansurabdulmalik
# 2                           nickaguirre
# 3                            amiralbazi
# 4                          junioralbini
#
# ('index', 'fight_id')                                    event        date  \
# 0                      UFC Fight Night 132: Cowboy vs. Edwards  2018-06-23
# 1                                                          UFC  2024-11-10
# 2                                          UFC Fight Night 218  2023-01-14
# 3                            UFC on ESPN: Hermansson vs. Allen  2023-06-03
# 4                                UFC 224: Nunes vs. Pennington  2018-05-12
#
# ('index', 'fight_id')        opponent                         timestep-1  \
# 0                         lijingliang  2018-06-13 12:09:00 - price: +240
# 1                      duskotodorovic  2024-10-27 17:16:00 - price: -360
# ...

# %%
for date, group in df.groupby('date'):
    print(f"Date: {date}")
    for _, row in group.iterrows():
        print(f" - {row['fighter']} vs {row['opponent']}")
    print("-----------------------------")
# Out:
# Date: 2007-09-08
#  - Matt Hamill vs Michael Bisping
# -----------------------------
# Date: 2007-09-19
#  - Thiago Alves vs Kuniyoshi Hironaka
# -----------------------------
# Date: 2007-11-17
#  - Houston Alexander vs Thiago Silva
#  - Ryo Chonan vs Karo Parisyan
#  - Rashad Evans vs Michael Bisping
# -----------------------------
# Date: 2007-12-29
#  - Eddie Sanchez vs Soa Palelei
# -----------------------------
# Date: 2008-02-02
#  - Frank Mir vs Brock Lesnar
# -----------------------------
# Date: 2008-03-01
#  - Cheick Kongo vs Heath Herring
# -----------------------------
# Date: 2008-04-02
#  - Thiago Alves vs Karo Parisyan
# -----------------------------
# Date: 2008-04-19
#  - Charles McCarthy vs Michael Bisping
#  - Nate Quarry vs Kalib Starnes
# -----------------------------
# Date: 2008-06-07
#  - Jason Day vs Michael Bisping
#  - Martin Kampmann vs Jorge Rivera
# -----------------------------
# Date: 2008-07-05
#  - Joe Stevenson vs Gleison Tibau
# ...
