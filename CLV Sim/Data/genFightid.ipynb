# %%
import pandas as pd
import numpy as np
import uuid

# %%
df = pd.read_csv("trainSequences.csv", header=None, names=range(231))
df.columns = df.iloc[0]
df = df[1:]
df.reset_index(drop=True, inplace=True)
df
# Out:
# C:\Users\maxbr\AppData\Local\Temp\ipykernel_13672\3664135840.py:1: DtypeWarning: Columns (192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("trainSequences.csv", header=None, names=range(231))
# 0                       fighter  \
# 0                    Daichi Abe
# 1                    Juan Adams
# 2                 Klidson Abreu
# 3                 Ricardo Abreu
# 4                 Kevin Aguilar
# ...                         ...
# 9640                 Fares Ziam
# 9641  Elizeu Zaleski dos Santos
# 9642                 Fares Ziam
# 9643                 Rani Yahya
# 9644                 Fares Ziam
#
# 0                                             event        date  \
# 0           UFC Fight Night 132: Cowboy vs. Edwards  2018-06-23
# ...

# %%
df['fighter'] = df['fighter'].replace('Rogerio Nogueira', 'Antonio Rogerio Nogueira')
df['opponent'] = df['opponent'].replace('Rogerio Nogueira', 'Antonio Rogerio Nogueira')

df['fighter'] = df['fighter'].replace('Marcos Rogerio', 'Marcos Rogerio de Lima')
df['opponent'] = df['opponent'].replace('Marcos Rogerio', 'Marcos Rogerio de Lima')

df['fighter'] = df['fighter'].replace('Ovince St Preux', 'Ovince Saint Preux')
df['opponent'] = df['opponent'].replace('Ovince St Preux', 'Ovince Saint Preux')


df['fighter'] = df['fighter'].replace('Ian Garry', 'Ian Machado Garry')
df['opponent'] = df['opponent'].replace('Ian Garry', 'Ian Machado Garry')


df['fighter'] = df['fighter'].replace('Loopy Godinez', 'Lupita Godinez')
df['opponent'] = df['opponent'].replace('Loopy Godinez', 'Lupita Godinez')

df['fighter'] = df['fighter'].replace('Blood Diamond', 'Mike Mathetha')
df['opponent'] = df['opponent'].replace('Blood Diamond', 'Mike Mathetha')

df['fighter'] = df['fighter'].replace('Alex Hernandez', 'Alexander Hernandez')
df['opponent'] = df['opponent'].replace('Alex Hernandez', 'Alexander Hernandez')


df['fighter'] = df['fighter'].replace('Da Woon Jung', 'Da Un Jung')
df['opponent'] = df['opponent'].replace('Da Woon Jung', 'Da Un Jung')

df['fighter'] = df['fighter'].replace('Tiago dos Santos', 'Tiago dos Santos e Silva')
df['opponent'] = df['opponent'].replace('Tiago dos Santos', 'Tiago dos Santos e Silva')

df['fighter'] = df['fighter'].replace('Costas Philippou', 'Constantinos Philippou')
df['opponent'] = df['opponent'].replace('Costas Philippou', 'Constantinos Philippou')

df['fighter'] = df['fighter'].replace('Robbie Peralta', 'Robert Peralta')
df['opponent'] = df['opponent'].replace('Robbie Peralta', 'Robert Peralta')

df['fighter'] = df['fighter'].replace('Elizeu Zaleski', 'Elizeu Zaleski dos Santos')
df['opponent'] = df['opponent'].replace('Elizeu Zaleski', 'Elizeu Zaleski dos Santos')

df['fighter'] = df['fighter'].replace('Hector Aldana', 'Gilbert Aldana')
df['opponent'] = df['opponent'].replace('Hector Aldana', 'Gilbert Aldana')

df['fighter'] = df['fighter'].replace('Bill Duvall', 'Bill Algeo')
df['opponent'] = df['opponent'].replace('Bill Duvall', 'Bill Algeo')

df['fighter'] = df['fighter'].replace('Joel Thomas', 'Joel Alvarez')
df['opponent'] = df['opponent'].replace('Joel Thomas', 'Joel Alvarez')

df['fighter'] = df['fighter'].replace('Cesar Marscucci', 'Cesar Almeida')
df['opponent'] = df['opponent'].replace('Cesar Marscucci', 'Cesar Almeida')

df['fighter'] = df['fighter'].replace('Sam Hoger', 'Sam Alvey')
df['opponent'] = df['opponent'].replace('Sam Hoger', 'Sam Alvey')

df['fighter'] = df['fighter'].replace('Montserrat Ruiz', 'Montserrat Conejo Ruiz')
df['opponent'] = df['opponent'].replace('Montserrat Ruiz', 'Montserrat Conejo Ruiz')

df['fighter'] = df['fighter'].replace('Khalil Rountree Jr', 'Khalil Rountree')
df['opponent'] = df['opponent'].replace('Khalil Rountree Jr', 'Khalil Rountree')

df['fighter'] = df['fighter'].replace('Yohan Banks', 'Yohan Lainesse')
df['opponent'] = df['opponent'].replace('Yohan Banks', 'Yohan Lainesse')

df['fighter'] = df['fighter'].replace('Scott Bessac', 'Brad Scott')
df['opponent'] = df['opponent'].replace('Scott Bessac', 'Brad Scott')

df['fighter'] = df['fighter'].replace('Scott Ferrozzo', 'Brad Scott')
df['opponent'] = df['opponent'].replace('Scott Ferrozzo', 'Brad Scott')

df['fighter'] = df['fighter'].replace('Scott Fiedler', 'Brad Scott')
df['opponent'] = df['opponent'].replace('Scott Fiedler', 'Brad Scott')

df['fighter'] = df['fighter'].replace('Diego Ferreira', 'Carlos Diego Ferreira')
df['fighter'] = df['fighter'].replace('Diego Ferreira', 'Carlos Diego Ferreira')

df['fighter'] = df['fighter'].replace('Edson Silva', 'Edson Barboza')
df['opponent'] = df['opponent'].replace('Edson Silva', 'Edson Barboza')

df['fighter'] = df['fighter'].replace('Glaico Franca', 'Glaico Franca Moreira')
df['opponent'] = df['opponent'].replace('Glaico Franca', 'Glaico Franca Moreira')

df['fighter'] = df['fighter'].replace('Maheshate', 'Hayisaer Maheshate')
df['opponent'] = df['opponent'].replace('Maheshate', 'Hayisaer Maheshate')

df['fighter'] = df['fighter'].replace('Billy Goff', 'Billy Ray Goff')
df['opponent'] = df['opponent'].replace('Billy Goff', 'Billy Ray Goff')

df['fighter'] = df['fighter'].replace('Josh Burkman', 'Joshua Burkman')
df['opponent'] = df['opponent'].replace('Josh Burkman', 'Joshua Burkman')


df['fighter'] = df['fighter'].replace('Herman Renting', 'Dave Herman')
df['opponent'] = df['opponent'].replace('Herman Renting', 'Dave Herman')

df['fighter'] = df['fighter'].replace('Ed Herman', 'Dave Herman')
df['opponent'] = df['opponent'].replace('Ed Herman', 'Dave Herman')

df['fighter'] = df['fighter'].replace('Alvaro Herrera', 'Alvaro Herrera Mendoza')
df['opponent'] = df['opponent'].replace('Alvaro Herrera', 'Alvaro Herrera Mendoza')


df['fighter'] = df['fighter'].replace('Ion Cherdivara', 'Ion Cutelaba')
df['opponent'] = df['opponent'].replace('Ion Cherdivara', 'Ion Cutelaba')

df['fighter'] = df['fighter'].replace('Jadson Costa', 'Alessandro Costa')
df['opponent'] = df['opponent'].replace('Jadson Costa', 'Alessandro Costa')

df['fighter'] = df['fighter'].replace('Luiz Dutra', 'Luiz Dutra Jr')
df['opponent'] = df['opponent'].replace('Luiz Dutra', 'Luiz Dutra Jr')

df['fighter'] = df['fighter'].replace('Rolando Dy', 'Rolando Bedoya')



df = df.drop_duplicates().reset_index(drop=True)

# %%
df
# Out:
# 0                       fighter  \
# 0                    Daichi Abe
# 1                    Juan Adams
# 2                 Klidson Abreu
# 3                 Ricardo Abreu
# 4                 Kevin Aguilar
# ...                         ...
# 9549                 Fares Ziam
# 9550  Elizeu Zaleski dos Santos
# 9551                 Fares Ziam
# 9552                 Rani Yahya
# 9553                 Fares Ziam
#
# 0                                             event        date  \
# 0           UFC Fight Night 132: Cowboy vs. Edwards  2018-06-23
# 1              UFC on ESPN 4: Dos Anjos vs. Edwards  2019-07-20
# 2                 UFC on ESPN+ 21: Zabit vs. Kattar  2019-11-09
# 3         UFC Fight Night 68: Henderson vs. Boetsch  2015-06-06
# 4                    UFC 262: Oliveira vs. Chandler  2021-05-15
# ...                                             ...         ...
# 9549                UFC 263: Adesanya vs. Vettori 2  2021-06-12
# ...

# %%
df_clean = df.copy()

# %%
def clean_and_sort(name):
    cleaned = str(name).replace("'", '').replace(' ', '').replace('-', '').lower()
    return ''.join(sorted(cleaned))

# %%
df_clean['fighter'] = df_clean['fighter'].apply(clean_and_sort)
df_clean['opponent'] = df_clean['opponent'].apply(clean_and_sort)
df_clean.head()
# Out:
# 0       fighter                                      event        date  \
# 0     aabcdehii    UFC Fight Night 132: Cowboy vs. Edwards  2018-06-23
# 1     aaadjmnsu       UFC on ESPN 4: Dos Anjos vs. Edwards  2019-07-20
# 2  abdeiklnorsu          UFC on ESPN+ 21: Zabit vs. Kattar  2019-11-09
# 3  aabcdeiorrru  UFC Fight Night 68: Henderson vs. Boetsch  2015-06-06
# 4  aaegiiklnruv             UFC 262: Oliveira vs. Chandler  2021-05-15
#
# 0        opponent                         timestep-1  \
# 0     aggiiijllnn  2018-06-13 12:09:00 - price: +240
# 1       adegghrry  2019-06-30 17:33:00 - price: -155
# 2  aaaghilmmostvz  2019-10-28 12:36:00 - price: +190
# 3     aceeijkllor  2015-05-30 19:18:00 - price: -210
# 4      ceklrttuuz  2021-04-26 17:20:00 - price: -110
#
# 0                         timestep-2                         timestep-3  \
# 0  2018-06-13 12:21:00 - price: +325  2018-06-13 13:42:00 - price: +315
# ...

# %%
df.insert(0, 'fight_id', np.nan)
df.head()
# Out:
# 0  fight_id        fighter                                      event  \
# 0       NaN     Daichi Abe    UFC Fight Night 132: Cowboy vs. Edwards
# 1       NaN     Juan Adams       UFC on ESPN 4: Dos Anjos vs. Edwards
# 2       NaN  Klidson Abreu          UFC on ESPN+ 21: Zabit vs. Kattar
# 3       NaN  Ricardo Abreu  UFC Fight Night 68: Henderson vs. Boetsch
# 4       NaN  Kevin Aguilar             UFC 262: Oliveira vs. Chandler
#
# 0        date         opponent                         timestep-1  \
# 0  2018-06-23     Li Jingliang  2018-06-13 12:09:00 - price: +240
# 1  2019-07-20       Greg Hardy  2019-06-30 17:33:00 - price: -155
# 2  2019-11-09  Shamil Gamzatov  2019-10-28 12:36:00 - price: +190
# 3  2015-06-06     Jake Collier  2015-05-30 19:18:00 - price: -210
# 4  2021-05-15      Tucker Lutz  2021-04-26 17:20:00 - price: -110
#
# 0                         timestep-2                         timestep-3  \
# ...

# %%
for index, row in df.iterrows():
    fighter = df_clean.loc[index, 'fighter']
    opponent = df_clean.loc[index, 'opponent']
    date = row['date']
    fight_id = row['fight_id']

    if not pd.isna(fight_id):
        continue

    opposing_sequence = df_clean[
        (df_clean['fighter'] == opponent) &
        (df_clean['opponent'] == fighter) &
        (df_clean['date'] == date)
    ]

    if not opposing_sequence.empty:
        new_uuid = uuid.uuid4()
        df.loc[index, 'fight_id'] = new_uuid
        df.loc[opposing_sequence.index[0], 'fight_id'] = new_uuid
# Out:
# C:\Users\maxbr\AppData\Local\Temp\ipykernel_13672\1834193797.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'b78e06f8-0b6f-4b57-82d1-78ab635b7498' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[index, 'fight_id'] = new_uuid

# %%
print(df['fight_id'].isna().sum())
# Out:
# 1819

# %%
df[df['fight_id'].isna()].reset_index().to_csv('missing_fight_ids.csv', index=False)

# %%
df.to_csv('trainSequencesKeys.csv')

# %%
df = pd.read_csv("missing_fight_ids.csv", header=None, names=range(231))
df.columns = df.iloc[0]
df = df[1:]
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
# ('index', 'fight_id')             fighter  \
# 0                              Daichi Abe
# 1                      Mansur Abdul-Malik
# 2                            Nick Aguirre
# 3                             Amir Albazi
# 4                           Junior Albini
#
# ('index', 'fight_id')                                    event        date  \
# 0                      UFC Fight Night 132: Cowboy vs. Edwards  2018-06-23
# 1                                                          UFC  2024-11-10
# 2                                          UFC Fight Night 218  2023-01-14
# 3                            UFC on ESPN: Hermansson vs. Allen  2023-06-03
# 4                                UFC 224: Nunes vs. Pennington  2018-05-12
#
# ('index', 'fight_id')         opponent                         timestep-1  \
# 0                         Li Jingliang  2018-06-13 12:09:00 - price: +240
# 1                      Dusko Todorovic  2024-10-27 17:16:00 - price: -360
# ...

# %%
timestamp_cols = [col for col in df.columns if col.startswith('timestep-')]
df_clean = df.copy()

# Clean all timestamps: keep only the part before " - price: "
for col in timestamp_cols:
    df_clean[col] = df_clean[col].astype(str).str.split(' - price: ').str[0]

for index, row in df_clean.iterrows():
    current_timestamps = set(row[timestamp_cols])

    def count_matches(other_row):
        return len(current_timestamps.intersection(set(other_row[timestamp_cols])))

    match_counts = df_clean.drop(index).apply(count_matches, axis=1)
    matches = match_counts[match_counts >= 20]

    if not matches.empty:
        for match_index in matches.index:
            matched_row = df_clean.loc[match_index]
            print(f"Match found:")
            print(f" - Current: fighter = {row['fighter']}, opponent = {row['opponent']}")
            print(f" - Match:  fighter = {matched_row['fighter']}, opponent = {matched_row['opponent']}")
            print(f" - Shared timestamps = {match_counts[match_index]}\n")
            print(f"-----------------FIX CODE------------------")
            print(f"df['fighter'] = df['fighter'].replace('{matched_row['fighter']}', '{row['fighter']}')")
            print(f"df['opponent'] = df['opponent'].replace('{matched_row['fighter']}', '{row['fighter']}')")
            print(f"-------------FIX CODE OTHER-------------")
            print(f"df['fighter'] = df['fighter'].replace('{matched_row['opponent']}', '{row['opponent']}')")
            print(f"df['opponent'] = df['opponent'].replace('{matched_row['opponent']}', '{row['opponent']}')")
            print(f"-------------FIX CODE OTHER-------------")
            print(f"df['fighter'] = df['fighter'].replace('{matched_row['fighter']}', '{row['opponent']}')")
            print(f"df['opponent'] = df['opponent'].replace('{matched_row['fighter']}', '{row['opponent']}')")
            print("\n\n\n")
# Out:
# Match found:
#  - Current: fighter = Rolando Bedoya, opponent = Song Kenan
#  - Match:  fighter = Rolando Dy, opponent = Song Kenan
#  - Shared timestamps = 68
#
# -----------------FIX CODE------------------
# df['fighter'] = df['fighter'].replace('Rolando Dy', 'Rolando Bedoya')
# df['opponent'] = df['opponent'].replace('Rolando Dy', 'Rolando Bedoya')
# -------------FIX CODE OTHER-------------
# df['fighter'] = df['fighter'].replace('Song Kenan', 'Song Kenan')
# df['opponent'] = df['opponent'].replace('Song Kenan', 'Song Kenan')
# -------------FIX CODE OTHER-------------
# df['fighter'] = df['fighter'].replace('Rolando Dy', 'Song Kenan')
# df['opponent'] = df['opponent'].replace('Rolando Dy', 'Song Kenan')
#
#
#
#
# Match found:
#  - Current: fighter = Tanner Boser, opponent = Ion Curelaba
#  - Match:  fighter = Ion Cutelaba, opponent = Tanner Boser
#  - Shared timestamps = 68
#
# -----------------FIX CODE------------------
# ...
